# %%
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
import csv
from scipy import stats
import scipy.linalg as la
import math
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Importar Datos (no se importan los datos de errores ya que se omitirá este problema al ser una primera aproximación)
datos = np.loadtxt("antofagasta.dat")
latitud   = datos[:,0]
longitud   = datos[:,1]
uEast    = datos[:,2]
uNorth   = datos[:,4]

#Grados a Radianes
latitud =  latitud*(np.pi/180)
longitud = longitud*(np.pi/180)

#Tamaño de los vectores
length  = latitud.shape[0]

#inicializar varibles importantes
p1 = 0
p2 = 0
p3 = 0
p4 = 0
p5 = 0

#Coordenadas de Lat-Lon a UTM, usando relaciones entre los sistemas geodéticos y constantes propuestas
#Aquí se establece el sistema de referencia común
po = 0.9996
c  = 0.007
e  = 0.08

a  = 6378137
b  = 6356752.3142
n  = (a-b)/(a+b)


#Funciones que determinan las conversiones ncesarias para pasar a UTM
def conversion2(k):
    kk = a*((1-e**2/4-3*e**4/64-5*e**6/256)*k-(3*e**2/8+3*e**4/32+45*e**6/1024)*np.sin(2*k)+(15*e**4/256 + 45*e**6/1024)*np.sin(4*k) - (35*e**6/3072)*np.sin(6*k))
    return kk

def conversion(k):
    kk = a/((1-e**2*(np.sin(k))**2)**(1/2))
    return kk


#Inicializar verctores
latitudUTM = np.zeros(length)
longitudUTM = np.zeros(length)

#Conversion final a UTM
for i in range (0, length):
    lat = latitud[i]
    p2=po*conversion(lat)*np.sin(lat)*np.cos(lat)*0.5
    p3=(po*conversion(lat)*np.sin(lat)*(np.cos(lat))**3*(1/24))*(5-(np.tan(lat))**2+9*c*(np.cos(lat))**2+4*c**2*(np.cos(lat))**4)
    p5=(po*conversion(lat)*(np.cos(lat))**3*(1/6))*(1-(np.tan(lat)**2)+c*(np.cos(lat))**2)
        
    ppp = longitud[i]
    l = 291*(np.pi/180)
    p = ppp -l
    
    v1=po*(conversion2(lat))+(p2*p**2)+(p3*p**4)
    v2=(po*conversion(lat)*np.cos(lat)*p)+(p5*p**3)
    
    latitudUTM[i] = v1
    longitudUTM[i] = v2

# %%
#The following process was used using the proposed procedure in the book of Allmendinger, R. W., 2012. Strcutural Geology Algorithms. 
#Cambridge. 144-145.

#Mean vector, overall orientations
UE = 0
UN = 0
for i in range (0, length):
    UE = UE + uEast[i]
    UN = UN + uNorth[i]
    
UE=UE/length
UN=UN/length

#Transformation matrix for X1'
t11 = np.arctan(UE/UN)
t12 = (np.pi)/2-t11
t22 = t11
t21 = (np.pi)/2+t22
a11 = np.cos(t11)
a12 = np.cos(t12)
a21 = np.cos(t21)
a22 = np.cos(t22)

#Transform the east and north coordinates of the GPS vectors
latTrans = np.zeros(length)
lonTrans = np.zeros(length)
for i in range (0, length):
    v1=latitudUTM[i]
    v2=longitudUTM[i]    
    v1p = v1*a11+v2*a12
    v2p = v2*a21+v2*a22
    latTrans[i] = v1p
    lonTrans[i] = v2p

# %%
#Estimar la parte simétrica del tensor de deformación usando εij=(1/2)*(eij+eji)
def simetria(eij, eji):
    eeij=(1/2)*(eij+eji)
    return eeij

#Inicializar tensores de deformación
s=(2,2)
e=zeros(s)
e1=zeros(s)
e2=zeros(s)
e3=zeros(s)
e4=zeros(s)
e5=zeros(s)
e6=zeros(s)
e7=zeros(s)
e8=zeros(s)
e9=zeros(s)
e10=zeros(s)
e11=zeros(s)
e12=zeros(s)
e13=zeros(s)
e14=zeros(s)
e15=zeros(s)
e16=zeros(s)
e17=zeros(s)
e18=zeros(s)
e19=zeros(s)
e20=zeros(s)
e21=zeros(s)
e22=zeros(s)
e23=zeros(s)
e24=zeros(s)
e25=zeros(s)
e26=zeros(s)
e27=zeros(s)
e28=zeros(s)
e29=zeros(s)
e30=zeros(s)

#Calcular los tensores de deformación
e[0,0]=uEast[0]/latTrans[0]
e[0,1]=simetria(uNorth[0]/latTrans[0],uEast[0]/lonTrans[0])
e[1,0]=simetria(uNorth[0]/latTrans[0],uEast[0]/lonTrans[0])
e[1,1]=uNorth[0]/lonTrans[0]
e1[0,0]=uEast[1]/latTrans[1]
e1[0,1]=simetria(uNorth[1]/latTrans[1],uEast[1]/lonTrans[1])
e1[1,0]=simetria(uNorth[1]/latTrans[1],uEast[1]/lonTrans[1])
e1[1,1]=uNorth[1]/lonTrans[1]
e2[0,0]=uEast[2]/latTrans[2]
e2[0,1]=simetria(uNorth[2]/latTrans[2],uEast[2]/lonTrans[2])
e2[1,0]=simetria(uNorth[2]/latTrans[2],uEast[2]/lonTrans[2])
e2[1,1]=uNorth[2]/lonTrans[2]   

e3[0,0]=uEast[3]/latTrans[3]
e3[0,1]=simetria(uNorth[3]/latTrans[3],uEast[3]/lonTrans[3])
e3[1,0]=simetria(uNorth[3]/latTrans[3],uEast[3]/lonTrans[3])
e3[1,1]=uNorth[3]/lonTrans[3]
e4[0,0]=uEast[4]/latTrans[4]
e4[0,1]=simetria(uNorth[4]/latTrans[4],uEast[4]/lonTrans[4])
e4[1,0]=simetria(uNorth[4]/latTrans[4],uEast[4]/lonTrans[4])
e4[1,1]=uNorth[4]/lonTrans[4]
e5[0,0]=uEast[5]/latTrans[5]
e5[0,1]=simetria(uNorth[5]/latTrans[5],uEast[5]/lonTrans[5])
e5[1,0]=simetria(uNorth[5]/latTrans[5],uEast[5]/lonTrans[5])
e5[1,1]=uNorth[5]/lonTrans[5] 

e6[0,0]=uEast[6]/latTrans[6]
e6[0,1]=simetria(uNorth[6]/latTrans[6],uEast[6]/lonTrans[6])
e6[1,0]=simetria(uNorth[6]/latTrans[6],uEast[6]/lonTrans[6])
e6[1,1]=uNorth[6]/lonTrans[6]
e7[0,0]=uEast[7]/latTrans[7]
e7[0,1]=simetria(uNorth[7]/latTrans[7],uEast[7]/lonTrans[7])
e7[1,0]=simetria(uNorth[7]/latTrans[7],uEast[7]/lonTrans[7])
e7[1,1]=uNorth[7]/lonTrans[7]
e8[0,0]=uEast[8]/latTrans[8]
e8[0,1]=simetria(uNorth[8]/latTrans[8],uEast[8]/lonTrans[8])
e8[1,0]=simetria(uNorth[8]/latTrans[8],uEast[8]/lonTrans[8])
e8[1,1]=uNorth[8]/lonTrans[8]   

e9[0,0]=uEast[9]/latTrans[9]
e9[0,1]=simetria(uNorth[9]/latTrans[9],uEast[9]/lonTrans[9])
e9[1,0]=simetria(uNorth[9]/latTrans[9],uEast[9]/lonTrans[9])
e9[1,1]=uNorth[9]/lonTrans[9]
e10[0,0]=uEast[10]/latTrans[10]
e10[0,1]=simetria(uNorth[10]/latTrans[10],uEast[10]/lonTrans[10])
e10[1,0]=simetria(uNorth[10]/latTrans[10],uEast[10]/lonTrans[10])
e10[1,1]=uNorth[10]/lonTrans[10]
e11[0,0]=uEast[11]/latTrans[11]
e11[0,1]=simetria(uNorth[11]/latTrans[11],uEast[11]/lonTrans[11])
e11[1,0]=simetria(uNorth[11]/latTrans[11],uEast[11]/lonTrans[11])
e11[1,1]=uNorth[11]/lonTrans[11]

e12[0,0]=uEast[12]/latTrans[12]
e12[0,1]=simetria(uNorth[12]/latTrans[12],uEast[12]/lonTrans[12])
e12[1,0]=simetria(uNorth[12]/latTrans[12],uEast[12]/lonTrans[12])
e12[1,1]=uNorth[12]/lonTrans[12]
e13[0,0]=uEast[13]/latTrans[13]
e13[0,1]=simetria(uNorth[13]/latTrans[13],uEast[13]/lonTrans[13])
e13[1,0]=simetria(uNorth[13]/latTrans[13],uEast[13]/lonTrans[13])
e13[1,1]=uNorth[13]/lonTrans[13]
e14[0,0]=uEast[14]/latTrans[14]
e14[0,1]=simetria(uNorth[14]/latTrans[14],uEast[14]/lonTrans[14])
e14[1,0]=simetria(uNorth[14]/latTrans[14],uEast[14]/lonTrans[14])
e14[1,1]=uNorth[14]/lonTrans[14]

e15[0,0]=uEast[15]/latTrans[15]
e15[0,1]=simetria(uNorth[15]/latTrans[15],uEast[15]/lonTrans[15])
e15[1,0]=simetria(uNorth[15]/latTrans[15],uEast[15]/lonTrans[15])
e15[1,1]=uNorth[15]/lonTrans[15]
e16[0,0]=uEast[16]/latTrans[16]
e16[0,1]=simetria(uNorth[16]/latTrans[16],uEast[16]/lonTrans[16])
e16[1,0]=simetria(uNorth[16]/latTrans[16],uEast[16]/lonTrans[16])
e16[1,1]=uNorth[16]/lonTrans[16]
e17[0,0]=uEast[17]/latTrans[17]
e17[0,1]=simetria(uNorth[17]/latTrans[17],uEast[17]/lonTrans[17])
e17[1,0]=simetria(uNorth[17]/latTrans[17],uEast[17]/lonTrans[17])
e17[1,1]=uNorth[17]/lonTrans[17]

e18[0,0]=uEast[18]/latTrans[18]
e18[0,1]=simetria(uNorth[18]/latTrans[18],uEast[18]/lonTrans[18])
e18[1,0]=simetria(uNorth[18]/latTrans[18],uEast[18]/lonTrans[18])
e18[1,1]=uNorth[18]/lonTrans[18]
e19[0,0]=uEast[19]/latTrans[19]
e19[0,1]=simetria(uNorth[19]/latTrans[19],uEast[19]/lonTrans[19])
e19[1,0]=simetria(uNorth[19]/latTrans[19],uEast[19]/lonTrans[19])
e19[1,1]=uNorth[19]/lonTrans[19]
e20[0,0]=uEast[20]/latTrans[20]
e20[0,1]=simetria(uNorth[20]/latTrans[20],uEast[20]/lonTrans[20])
e20[1,0]=simetria(uNorth[20]/latTrans[20],uEast[20]/lonTrans[20])
e20[1,1]=uNorth[20]/lonTrans[20]

e21[0,0]=uEast[21]/latTrans[21]
e21[0,1]=simetria(uNorth[21]/latTrans[21],uEast[21]/lonTrans[21])
e21[1,0]=simetria(uNorth[21]/latTrans[21],uEast[21]/lonTrans[21])
e21[1,1]=uNorth[21]/lonTrans[21]
e22[0,0]=uEast[22]/latTrans[22]
e22[0,1]=simetria(uNorth[22]/latTrans[22],uEast[22]/lonTrans[22])
e22[1,0]=simetria(uNorth[22]/latTrans[22],uEast[22]/lonTrans[22])
e22[1,1]=uNorth[22]/lonTrans[22]
e23[0,0]=uEast[23]/latTrans[23]
e23[0,1]=simetria(uNorth[23]/latTrans[23],uEast[23]/lonTrans[23])
e23[1,0]=simetria(uNorth[23]/latTrans[23],uEast[23]/lonTrans[23])
e23[1,1]=uNorth[23]/lonTrans[23]

e24[0,0]=uEast[24]/latTrans[24]
e24[0,1]=simetria(uNorth[24]/latTrans[24],uEast[24]/lonTrans[24])
e24[1,0]=simetria(uNorth[24]/latTrans[24],uEast[24]/lonTrans[24])
e24[1,1]=uNorth[24]/lonTrans[24]
e25[0,0]=uEast[25]/latTrans[25]
e25[0,1]=simetria(uNorth[25]/latTrans[25],uEast[25]/lonTrans[25])
e25[1,0]=simetria(uNorth[25]/latTrans[25],uEast[25]/lonTrans[25])
e25[1,1]=uNorth[25]/lonTrans[25]
e26[0,0]=uEast[26]/latTrans[26]
e26[0,1]=simetria(uNorth[26]/latTrans[26],uEast[26]/lonTrans[26])
e26[1,0]=simetria(uNorth[26]/latTrans[26],uEast[26]/lonTrans[26])
e26[1,1]=uNorth[26]/lonTrans[26]

e27[0,0]=uEast[27]/latTrans[27]
e27[0,1]=simetria(uNorth[27]/latTrans[27],uEast[27]/lonTrans[27])
e27[1,0]=simetria(uNorth[27]/latTrans[27],uEast[27]/lonTrans[27])
e27[1,1]=uNorth[27]/lonTrans[27]
e28[0,0]=uEast[28]/latTrans[28]
e28[0,1]=simetria(uNorth[28]/latTrans[28],uEast[28]/lonTrans[28])
e28[1,0]=simetria(uNorth[28]/latTrans[28],uEast[28]/lonTrans[28])
e28[1,1]=uNorth[28]/lonTrans[28]
e29[0,0]=uEast[29]/latTrans[29]
e29[0,1]=simetria(uNorth[29]/latTrans[29],uEast[29]/lonTrans[29])
e29[1,0]=simetria(uNorth[29]/latTrans[29],uEast[29]/lonTrans[29])
e29[1,1]=uNorth[29]/lonTrans[29]

e30[0,0]=uEast[30]/latTrans[30]
e30[0,1]=simetria(uNorth[30]/latTrans[30],uEast[30]/lonTrans[30])
e30[1,0]=simetria(uNorth[30]/latTrans[30],uEast[30]/lonTrans[30])
e30[1,1]=uNorth[30]/lonTrans[30]

# %%
magvalor = np.zeros(length)
#Calcular los vectores propios y su norma para graficar
evals = la.eigvals(e)
magvalor[0]=np.linalg.norm(evals)
evals = la.eigvals(e1)
magvalor[1]=np.linalg.norm(evals)
evals = la.eigvals(e2)
magvalor[2]=np.linalg.norm(evals)
evals = la.eigvals(e3)
magvalor[3]=np.linalg.norm(evals)
evals = la.eigvals(e4)
magvalor[4]=np.linalg.norm(evals)
evals = la.eigvals(e5)
magvalor[5]=np.linalg.norm(evals)
evals = la.eigvals(e6)
magvalor[6]=np.linalg.norm(evals)
evals = la.eigvals(e7)
magvalor[7]=np.linalg.norm(evals)
evals = la.eigvals(e8)
magvalor[8]=np.linalg.norm(evals)
evals = la.eigvals(e9)
magvalor[9]=np.linalg.norm(evals)
evals = la.eigvals(e10)
magvalor[10]=np.linalg.norm(evals)
evals = la.eigvals(e11)
magvalor[11]=np.linalg.norm(evals)
evals = la.eigvals(e12)
magvalor[12]=np.linalg.norm(evals)
evals = la.eigvals(e13)
magvalor[13]=np.linalg.norm(evals)
evals = la.eigvals(e14)
magvalor[14]=np.linalg.norm(evals)
evals = la.eigvals(e15)
magvalor[15]=np.linalg.norm(evals)
evals = la.eigvals(e16)
magvalor[16]=np.linalg.norm(evals)
evals = la.eigvals(e17)
magvalor[17]=np.linalg.norm(evals)
evals = la.eigvals(e18)
magvalor[18]=np.linalg.norm(evals)
evals = la.eigvals(e19)
magvalor[19]=np.linalg.norm(evals)
evals = la.eigvals(e20)
magvalor[20]=np.linalg.norm(evals)
evals = la.eigvals(e21)
magvalor[21]=np.linalg.norm(evals)
evals = la.eigvals(e22)
magvalor[22]=np.linalg.norm(evals)
evals = la.eigvals(e23)
magvalor[23]=np.linalg.norm(evals)
evals = la.eigvals(e24)
magvalor[24]=np.linalg.norm(evals)
evals = la.eigvals(e25)
magvalor[25]=np.linalg.norm(evals)
evals = la.eigvals(e26)
magvalor[26]=np.linalg.norm(evals)
evals = la.eigvals(e27)
magvalor[27]=np.linalg.norm(evals)
evals = la.eigvals(e28)
magvalor[28]=np.linalg.norm(evals)
evals = la.eigvals(e29)
magvalor[29]=np.linalg.norm(evals)
evals = la.eigvals(e30)
magvalor[30]=np.linalg.norm(evals)

# %% [raw]
# Se calcula la norma que después se va a graficar

# %%
pos = np.zeros(length)
#Calcular la dirección de los autovectores con la norma de la dirección de latitud y longitud
def po(lat, lon):
    gg=math.sqrt(math.pow(lat,2)+math.pow(lon,2))
    return gg

#Llenar la matriz de posición con respectivos valores
pos[0]=po(latTrans[0],lonTrans[0])
pos[1]=po(latTrans[1],lonTrans[1])
pos[2]=po(latTrans[2],lonTrans[2])
pos[3]=po(latTrans[3],lonTrans[3])
pos[4]=po(latTrans[4],lonTrans[4])
pos[5]=po(latTrans[5],lonTrans[5])
pos[6]=po(latTrans[6],lonTrans[6])
pos[7]=po(latTrans[7],lonTrans[7])
pos[8]=po(latTrans[8],lonTrans[8])
pos[9]=po(latTrans[9],lonTrans[9])
pos[10]=po(latTrans[10],lonTrans[10])
pos[11]=po(latTrans[11],lonTrans[11])
pos[12]=po(latTrans[12],lonTrans[12])
pos[13]=po(latTrans[13],lonTrans[13])
pos[14]=po(latTrans[14],lonTrans[14])
pos[15]=po(latTrans[15],lonTrans[15])
pos[16]=po(latTrans[16],lonTrans[16])
pos[17]=po(latTrans[17],lonTrans[17])
pos[18]=po(latTrans[18],lonTrans[18])
pos[19]=po(latTrans[19],lonTrans[19])
pos[20]=po(latTrans[20],lonTrans[20])
pos[21]=po(latTrans[21],lonTrans[21])
pos[22]=po(latTrans[22],lonTrans[22])
pos[23]=po(latTrans[23],lonTrans[23])
pos[24]=po(latTrans[24],lonTrans[24])
pos[25]=po(latTrans[25],lonTrans[25])
pos[26]=po(latTrans[26],lonTrans[26])
pos[27]=po(latTrans[27],lonTrans[27])
pos[28]=po(latTrans[28],lonTrans[28])
pos[29]=po(latTrans[29],lonTrans[29])
pos[30]=po(latTrans[30],lonTrans[30])

# %% [markdown]
# Se calcularon las posiciones con la norma

# %%
py.scatter(pos, magvalor)

# %%
# determine best fit line for displacement in East
slope, intercept, r_value, p_value, std_err = stats.linregress(pos, magvalor)
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(pos[1:7], magvalor[1:7])
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(pos[15:30], magvalor[15:30])

print 'r value', r_value
print  'p_value', p_value
print 'standard deviation', std_err

print 'r value1', r_value1
print  'p_value1', p_value1
print 'standard deviation1', std_err1

print 'r value2', r_value2
print  'p_value2', p_value2
print 'standard deviation2', std_err2

line = slope*pos+intercept
line1 = slope1*pos+intercept1
line2 = slope2*pos+intercept2
plot(pos,line,'r-',pos, magvalor,'o', pos,line1,'g-', pos,line2,'b-')
# Out:
# r value -0.803703047214
# p_value 5.20182611401e-08
# standard deviation 1.98806093201e-15
# r value1 -0.38592514696
# p_value1 0.449851781599
# standard deviation1 2.73168463206e-13
# r value2 -0.89180758253
# p_value2 7.96416145933e-06
# standard deviation2 5.86930708218e-16
# ...

# %% [markdown]
# Strain varies in two dimensions because gradients in displacement exist in two dimensions. There is clearly some stations with higher displacement, which are the ones located aproximately in the same area and closer to the epicenter. Once the positions of the stations get farther away, the magnitude of displacement tends to zero as can be spected as stress and strain have been accomodated in the lithosphere. If the scatter and the regression is done just over the highest displacement stations, the linear regression coeficient will get closer to 1, indicating that the strain can be effectively correlated to the earthquake results.
# Worth to take notice is the low magnitude values of 2 GPS stations with same distance as the biggest magnitude displacement stations; since the distance is taken from a common center point (UTM), those stations lie over a great circle and so, don't have to be over the earthquake epicenter but to the north or south of it.
